# %%
import pandas as pd
import numpy as np
import warnings

##Importación de los datos
data = pd.read_csv('evol1_ann_table1.csv')
data
# Out:
#       NODE_1_length_58499_cov_4.208781   7996  C  T  225.421    25 T.1  \
# 0     NODE_1_length_58499_cov_4.208781  19176  A  T  225.417  28.0   T
# 1     NODE_1_length_58499_cov_4.208781  28986  T  A  225.417  23.0   A
# 2     NODE_1_length_58499_cov_4.208781  38746  T  A  228.316  30.0   A
# 3     NODE_1_length_58499_cov_4.208781  38894  T  A  228.246  26.0   A
# 4     NODE_2_length_51549_cov_4.432322    119  A  C  225.417  17.0   C
# ..                                 ...    ... .. ..      ...   ...  ..
# 785  NODE_733_length_111_cov_10.750000     89  T  A  96.8051  26.0   A
# 786  NODE_733_length_111_cov_10.750000     93  T  C  102.134  24.0   C
# 787   NODE_772_length_109_cov_4.370370     75  G  A  93.9245  17.0   A
# 788  NODE_777_length_107_cov_26.480769     43  A  G   114.52  30.0   G
# 789  NODE_777_length_107_cov_26.480769     80  A  G  164.057  30.0   G
#
#                     missense_variant  MODERATE  KAGFDIAF_00010  ... null.16  \
# ...

# %%
data_ = data[data['25'] >= 30]
data_
# Out:
#       NODE_1_length_58499_cov_4.208781   7996      C         T  225.421    25  \
# 2     NODE_1_length_58499_cov_4.208781  38746      T         A  228.316  30.0
# 7     NODE_2_length_51549_cov_4.432322  37395      G         T  225.417  30.0
# 12    NODE_3_length_51316_cov_4.268430  41356      G         T  225.417  31.0
# 17    NODE_4_length_43486_cov_4.473326  16381      A         T  228.325  32.0
# 18    NODE_4_length_43486_cov_4.473326  34995  GGGTG  GGGTGGTG  228.332  33.0
# ..                                 ...    ...    ...       ...      ...   ...
# 782  NODE_733_length_111_cov_10.750000     59      G         A  92.4709  30.0
# 783  NODE_733_length_111_cov_10.750000     62      A         G   92.487  30.0
# 784  NODE_733_length_111_cov_10.750000     74      C         A  92.4507  30.0
# 788  NODE_777_length_107_cov_26.480769     43      A         G   114.52  30.0
# 789  NODE_777_length_107_cov_26.480769     80      A         G  164.057  30.0
#
# ...

# %%
data_evol1 = data_[data_['MODERATE']=='HIGH']
data_evol1
# Out:
#        NODE_1_length_58499_cov_4.208781   7996                    C  \
# 53    NODE_12_length_31822_cov_4.522649   3530                    T
# 63    NODE_16_length_28105_cov_4.645312  23540                    T
# 91    NODE_27_length_24632_cov_4.384058  21716                   TG
# 144   NODE_47_length_19935_cov_4.144920  15935                GAAAA
# 260  NODE_106_length_12735_cov_4.212618   5233                    T
# 275  NODE_108_length_12718_cov_4.092711  12416                    A
# 301  NODE_124_length_11842_cov_4.158395   9973  TCGGCGCGGCGCGGCGCGG
# 330  NODE_142_length_10787_cov_4.290719   4697                TGGGG
# 538   NODE_345_length_3705_cov_4.079178    749                    T
# 608   NODE_422_length_2271_cov_4.346119   1828                    T
#
#                   T  225.421    25             T.1  \
# 53               TG  225.417  38.0              TG
# 63                A  225.417  48.0               A
# 91              TGG  228.385  36.0             TGG
# ...

# %%
data_evol1.columns
# Out:
# Index(['NODE_1_length_58499_cov_4.208781', '7996', 'C', 'T', '225.421', '25',
#        'T.1', 'missense_variant', 'MODERATE', 'KAGFDIAF_00010',
#        ...
#        'null.16', 'Unnamed: 477', 'Unnamed: 478', 'n.7996C>T', 'Unnamed: 480',
#        'Unnamed: 481', 'Unnamed: 482', 'Unnamed: 483', 'Unnamed: 484',
#        'Unnamed: 485'],
#       dtype='object', length=486)

# %%
data_evol1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 53 to 608
# Columns: 486 entries, NODE_1_length_58499_cov_4.208781 to Unnamed: 485
# dtypes: float64(209), int64(1), object(276)
# memory usage: 38.0+ KB

# %%
data_evol1.to_csv("data_evol1.1.csv", index=False)

# %%
##Importación de los datos
data2 = pd.read_csv('evol2_ann_table1.csv')
data2
# Out:
#       NODE_1_length_58499_cov_4.208781   7996    C   T   225.417  44 T.1  \
# 0     NODE_1_length_58499_cov_4.208781  19176    A   T  225.4170  26   T
# 1     NODE_1_length_58499_cov_4.208781  28986    T   A  228.2720  27   A
# 2     NODE_1_length_58499_cov_4.208781  38746    T   A  225.4170  25   A
# 3     NODE_1_length_58499_cov_4.208781  38894    T   A  225.4170  28   A
# 4     NODE_2_length_51549_cov_4.432322   8023    A   T   38.9117  45   T
# ..                                 ...    ...  ...  ..       ...  ..  ..
# 731  NODE_713_length_135_cov_14.637500     54  CTT  CT  152.7780  33  CT
# 732  NODE_720_length_115_cov_13.583333     56    A   G   78.3756  14   G
# 733  NODE_720_length_115_cov_13.583333     58    C   G   78.3756  14   G
# 734  NODE_720_length_115_cov_13.583333     95    G   A   77.3972  13   A
# 735   NODE_772_length_109_cov_4.370370     75    G   A  148.6440  10   A
#
#                     missense_variant  MODERATE  KAGFDIAF_00010  ... null.16  \
# ...

# %%
data2_ = data2[data2['44'] >= 37]
data2_
# Out:
#      NODE_1_length_58499_cov_4.208781   7996  C  T   225.417  44 T.1  \
# 4    NODE_2_length_51549_cov_4.432322   8023  A  T   38.9117  45   T
# 9    NODE_3_length_51316_cov_4.268430  31317  G  T  225.4170  45   T
# 16   NODE_5_length_40631_cov_4.277208  22103  T  A  225.4170  61   A
# 18   NODE_6_length_40131_cov_4.614208  37977  A  T  225.4170  40   T
# 23   NODE_8_length_34660_cov_4.311718  15676  T  A  204.2460  39   A
# ..                                ...    ... .. ..       ...  ..  ..
# 725  NODE_703_length_156_cov_3.207921     68  C  T  214.8290  65   T
# 726  NODE_703_length_156_cov_3.207921     89  T  A  222.3990  59   A
# 727  NODE_703_length_156_cov_3.207921     90  T  C  221.5010  59   C
# 728  NODE_703_length_156_cov_3.207921    110  G  A   64.0348  48   A
# 729  NODE_703_length_156_cov_3.207921    134  T  C   86.2953  37   C
#
#           missense_variant  MODERATE  KAGFDIAF_00010  ... null.16  \
# 4         missense_variant  MODERATE  KAGFDIAF_00061  ...     NaN
# ...

# %%
df_filtrado2 = data2_[data2_['MODERATE']=='HIGH']

# %%
df_filtrado2
# Out:
#        NODE_1_length_58499_cov_4.208781   7996      C       T   225.417  44  \
# 44    NODE_12_length_31822_cov_4.522649   3530      T      TG  225.4170  46
# 55    NODE_16_length_28105_cov_4.645312  23540      T       A  225.4170  53
# 137   NODE_47_length_19935_cov_4.144920  15935  GAAAA  GAAAAA  228.1810  39
# 175   NODE_66_length_16713_cov_4.246668  14839     CA     CAA  222.4040  67
# 176   NODE_66_length_16713_cov_4.246668  14890    TAA      TA   40.2219  37
# 264  NODE_108_length_12718_cov_4.092711  12416      A       C  225.4170  47
#
#         T.1                 missense_variant MODERATE  KAGFDIAF_00010  ...  \
# 44       TG               frameshift_variant     HIGH  KAGFDIAF_00408  ...
# 55        A                      stop_gained     HIGH  KAGFDIAF_00530  ...
# 137  GAAAAA               frameshift_variant     HIGH  KAGFDIAF_01225  ...
# 175     CAA               frameshift_variant     HIGH  KAGFDIAF_01551  ...
# ...

# %%
#upstream, downstream, intragenic
data_evol2 = df_filtrado2[df_filtrado2['upstream_gene_variant'] != 'downstream_gene_variant']
data_evol2
# Out:
#        NODE_1_length_58499_cov_4.208781   7996      C       T   225.417  44  \
# 44    NODE_12_length_31822_cov_4.522649   3530      T      TG  225.4170  46
# 55    NODE_16_length_28105_cov_4.645312  23540      T       A  225.4170  53
# 137   NODE_47_length_19935_cov_4.144920  15935  GAAAA  GAAAAA  228.1810  39
# 175   NODE_66_length_16713_cov_4.246668  14839     CA     CAA  222.4040  67
# 176   NODE_66_length_16713_cov_4.246668  14890    TAA      TA   40.2219  37
# 264  NODE_108_length_12718_cov_4.092711  12416      A       C  225.4170  47
#
#         T.1                 missense_variant MODERATE  KAGFDIAF_00010  ...  \
# 44       TG               frameshift_variant     HIGH  KAGFDIAF_00408  ...
# 55        A                      stop_gained     HIGH  KAGFDIAF_00530  ...
# 137  GAAAAA               frameshift_variant     HIGH  KAGFDIAF_01225  ...
# 175     CAA               frameshift_variant     HIGH  KAGFDIAF_01551  ...
# ...

# %%
data_evol2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 44 to 264
# Columns: 486 entries, NODE_1_length_58499_cov_4.208781 to Unnamed: 485
# dtypes: float64(310), int64(2), object(174)
# memory usage: 22.8+ KB

# %%
data_evol2.to_csv("data_evol2.csv", index=False)
